# %% [markdown]
# # Trig plot
# Shows how to use Python to make a plot

# %%
% matplotlib inline
from matplotlib import pyplot as plt
import numpy as np
def f(x):
    return np.sin(x) * np.exp(-1 * np.sqrt(x))

xs = np.arange(0,20,0.1)
ys = f(xs)

r = plt.plot(xs,ys)
